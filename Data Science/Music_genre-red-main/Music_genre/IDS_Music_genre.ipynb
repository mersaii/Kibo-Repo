# %% [markdown]
# # Project Description ⛳
# <hr>
#
# **Your final project will involve all topics covered from Week 2 to 8 by using data to solve a real-life problem. Remember you're doing this with your team**.
#
# You’ve learned a ton about data collection and cleaning, visualization and insight, machine leearning, and model evaluation in this course. The final project is your chance to solve a problem with these from scratch.
#
#
# `Use the rubric below as a guideline for your project as this will be used in grading your submissions`.

# %% [markdown]
# # Data cleaning & preprocessing
#
# - Demonstrate clear understanding of different data cleaning and preprocessing techniques by applying them to your dataset.
# - Clearly document (within the notebook) all cleaning and preprocessing steps.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read in the data
df = pd.read_csv('music_genre.csv')

# Display first 5 rows
df.head()
# Out:
#            artist                                    song  \
# 0       Kate Bush  Running Up That Hill (A Deal With God)
# 1     The Killers                          Mr. Brightside
# 2  Arctic Monkeys                                     505
# 3      Sam Fender                   Seventeen Going Under
# 4     George Ezra                       Green Green Grass
#
#                       ids genre  acousticness  danceability  duration_ms  \
# 0  75FEaRjZTKLhTrFGsfMUXR  Rock       0.72000         0.629       298933
# 1  003vvx7Niy0yvhvHt4a68B  Rock       0.00121         0.352       222973
# 2  0BxE4FqsDD1Ot4YuBXwAPp  Rock       0.00287         0.526       253587
# 3  5rF6YUIlgiat22OT1lWspJ  Rock       0.00438         0.480       297933
# 4  3rk4aJ0vAj3cFUIQEeASkT  Rock       0.06950         0.685       167614
#
#    energy  instrumentalness  key  liveness  loudness  speechiness    tempo  \
# 0   0.547          0.003140   10    0.0604   -13.123       0.0550  108.375
# 1   0.911          0.000000    1    0.0995    -5.230       0.0747  148.033
# 2   0.866          0.000078    0    0.0945    -5.822       0.0568  140.266
# 3   0.870          0.006030    1    0.0826    -4.792       0.0362  161.953
# 4   0.738          0.000000    8    0.1280    -4.413       0.0595  112.972
#
#    mode  valence
# 0     0    0.197
# 1     1    0.236
# 2     1    0.248
# 3     1    0.584
# 4     1    0.800

# %%
df.isnull().sum()
# Out:
# artist              0
# song                0
# ids                 0
# genre               0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# speechiness         0
# tempo               0
# mode                0
# valence             0
# dtype: int64

# %%
#drop useless columns
df.drop(['ids'],axis=1,inplace=True)
df_without_song = df.drop(['song'],axis=1)
df_without_artist = df.drop(['artist'],axis=1)
df_without_artist_song = df.drop(['artist','song'],axis=1)

# %% [markdown]
# # Exploratory Data Analysis
# - Apply both measure of central tendency and dispersion to understand the data.
# - Perform corellation analysis of the dependent and independent variables
# - What does the corellation analysis says about the dependent and independent variables

# %%
#apply measures of central tendency and measures of dispersion on a dataset

#central tendencies without genre
mean = df_without_artist_song.drop(['genre'],axis=1).mean()
median = df_without_artist_song.drop(['genre'],axis=1).median()
mode = df_without_artist_song.drop(['genre'],axis=1).mode()

#measures of dispersion without genre
std = df_without_artist_song.drop(['genre'],axis=1).std()
var = df_without_artist_song.drop(['genre'],axis=1).var()
range = df_without_artist_song.drop(['genre'],axis=1).max() - df_without_artist_song.drop(['genre'],axis=1).min()

print("Measures of central tendency without genre")
print("Mean:")
print(mean)
print("Median:")
print(median)
print("Mode:")
print(mode)
print("Measures of dispersion without genre")
print("Standard deviation:")
print(std)
print("Variance:")
print(var)
print("Range:")
print(range)
# Out:
# Measures of central tendency without genre
# Mean:
# acousticness             0.339804
# danceability             0.578148
# duration_ms         230590.324000
# energy                   0.572698
# instrumentalness         0.187261
# key                      5.392000
# liveness                 0.146420
# loudness               -10.700616
# speechiness              0.071584
# tempo                  117.420964
# mode                     0.640000
# valence                  0.476311
# dtype: float64
# Median:
# acousticness             0.177000
# danceability             0.598000
# duration_ms         214460.000000
# energy                   0.660500
# instrumentalness         0.000107
# key                      6.000000
# liveness                 0.111000
# loudness                -6.709500
# speechiness              0.047250
# tempo                  120.045000
# mode                     1.000000
# valence                  0.469000
# dtype: float64
# Mode:
#     acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0          0.994         0.502       129965   0.713               0.0  7.0
# 1            NaN         0.601       157390   0.738               NaN  NaN
# 2            NaN         0.671       161533   0.862               NaN  NaN
# 3            NaN         0.687       169756     NaN               NaN  NaN
# 4            NaN         0.718       173097     NaN               NaN  NaN
# 5            NaN           NaN       177689     NaN               NaN  NaN
# 6            NaN           NaN       183955     NaN               NaN  NaN
# 7            NaN           NaN       202451     NaN               NaN  NaN
# 8            NaN           NaN       214460     NaN               NaN  NaN
# 9            NaN           NaN       214847     NaN               NaN  NaN
# 10           NaN           NaN       218365     NaN               NaN  NaN
# 11           NaN           NaN       237933     NaN               NaN  NaN
# 12           NaN           NaN       243228     NaN               NaN  NaN
# 13           NaN           NaN       250865     NaN               NaN  NaN
# 14           NaN           NaN       266179     NaN               NaN  NaN
# 15           NaN           NaN       308820     NaN               NaN  NaN
# 16           NaN           NaN       315427     NaN               NaN  NaN
# 17           NaN           NaN       336005     NaN               NaN  NaN
# 18           NaN           NaN       336924     NaN               NaN  NaN
# 19           NaN           NaN       391376     NaN               NaN  NaN
# 20           NaN           NaN       396000     NaN               NaN  NaN
# 21           NaN           NaN       438286     NaN               NaN  NaN
#
#     liveness  loudness  speechiness   tempo  mode  valence
# 0      0.106   -40.558       0.0298  99.988   1.0    0.464
# 1      0.110   -17.822       0.0346     NaN   NaN      NaN
# 2      0.111   -15.459          NaN     NaN   NaN      NaN
# 3      0.112   -12.653          NaN     NaN   NaN      NaN
# 4        NaN   -11.261          NaN     NaN   NaN      NaN
# 5        NaN   -10.971          NaN     NaN   NaN      NaN
# 6        NaN   -10.912          NaN     NaN   NaN      NaN
# 7        NaN   -10.611          NaN     NaN   NaN      NaN
# 8        NaN    -9.484          NaN     NaN   NaN      NaN
# 9        NaN    -8.290          NaN     NaN   NaN      NaN
# 10       NaN    -6.774          NaN     NaN   NaN      NaN
# 11       NaN    -4.869          NaN     NaN   NaN      NaN
# 12       NaN    -4.607          NaN     NaN   NaN      NaN
# 13       NaN    -4.541          NaN     NaN   NaN      NaN
# 14       NaN    -3.758          NaN     NaN   NaN      NaN
# 15       NaN    -3.240          NaN     NaN   NaN      NaN
# 16       NaN       NaN          NaN     NaN   NaN      NaN
# 17       NaN       NaN          NaN     NaN   NaN      NaN
# 18       NaN       NaN          NaN     NaN   NaN      NaN
# 19       NaN       NaN          NaN     NaN   NaN      NaN
# 20       NaN       NaN          NaN     NaN   NaN      NaN
# 21       NaN       NaN          NaN     NaN   NaN      NaN
# Measures of dispersion without genre
# Standard deviation:
# acousticness            0.365613
# danceability            0.172520
# duration_ms         67721.657776
# energy                  0.282715
# instrumentalness        0.359006
# key                     3.585773
# liveness                0.106238
# loudness                9.228730
# speechiness             0.069168
# tempo                  25.622608
# mode                    0.480963
# valence                 0.251459
# dtype: float64
# Variance:
# acousticness        1.336725e-01
# danceability        2.976312e-02
# duration_ms         4.586223e+09
# energy              7.992786e-02
# instrumentalness    1.288854e-01
# key                 1.285777e+01
# liveness            1.128656e-02
# loudness            8.516946e+01
# speechiness         4.784200e-03
# tempo               6.565180e+02
# mode                2.313253e-01
# valence             6.323172e-02
# dtype: float64
# Range:
# acousticness             0.995974
# danceability             0.856900
# duration_ms         427080.000000
# energy                   0.958800
# instrumentalness         0.978000
# key                     11.000000
# liveness                 0.738600
# loudness                37.908000
# speechiness              0.458700
# tempo                  155.216000
# mode                     1.000000
# valence                  0.929000
# dtype: float64

# %%
#correlation analysis of the independent variables with the dependent variable
corr = df_without_artist_song.drop(['genre'],axis=1).corr()
print("Correlation:")
print(corr)
# Out:
# Correlation:
#                   acousticness  danceability  duration_ms    energy  \
# acousticness          1.000000     -0.538718     0.184575 -0.858784
# danceability         -0.538718      1.000000    -0.309187  0.480816
# duration_ms           0.184575     -0.309187     1.000000 -0.202881
# energy               -0.858784      0.480816    -0.202881  1.000000
# instrumentalness      0.802812     -0.616671     0.289232 -0.803711
# key                   0.074325      0.110225    -0.092625  0.005436
# liveness             -0.217366      0.070571    -0.148772  0.263407
# loudness             -0.831313      0.564384    -0.204338  0.907639
# speechiness          -0.054851      0.227406    -0.122419  0.089217
# tempo                -0.214211     -0.038844     0.037738  0.245783
# mode                  0.021548     -0.132745     0.036440 -0.036138
# valence              -0.468351      0.487837    -0.343836  0.557997
#
#                   instrumentalness       key  liveness  loudness  speechiness  \
# acousticness              0.802812  0.074325 -0.217366 -0.831313    -0.054851
# danceability             -0.616671  0.110225  0.070571  0.564384     0.227406
# duration_ms               0.289232 -0.092625 -0.148772 -0.204338    -0.122419
# energy                   -0.803711  0.005436  0.263407  0.907639     0.089217
# instrumentalness          1.000000 -0.018490 -0.189212 -0.871203    -0.151969
# key                      -0.018490  1.000000  0.028660  0.010885     0.123567
# liveness                 -0.189212  0.028660  1.000000  0.217215     0.072116
# loudness                 -0.871203  0.010885  0.217215  1.000000     0.124465
# speechiness              -0.151969  0.123567  0.072116  0.124465     1.000000
# tempo                    -0.226062 -0.097113  0.056367  0.227803    -0.022887
# mode                     -0.057395 -0.213585 -0.041031 -0.002777    -0.136678
# valence                  -0.584943  0.014603  0.192959  0.527576    -0.049978
#
#                      tempo      mode   valence
# acousticness     -0.214211  0.021548 -0.468351
# danceability     -0.038844 -0.132745  0.487837
# duration_ms       0.037738  0.036440 -0.343836
# energy            0.245783 -0.036138  0.557997
# instrumentalness -0.226062 -0.057395 -0.584943
# key              -0.097113 -0.213585  0.014603
# liveness          0.056367 -0.041031  0.192959
# loudness          0.227803 -0.002777  0.527576
# speechiness      -0.022887 -0.136678 -0.049978
# tempo             1.000000  0.061389  0.111193
# mode              0.061389  1.000000  0.131118
# valence           0.111193  0.131118  1.000000

# %% [markdown]
# # Data Visualization & Insight
# - Use at least 5 different visuals to tell a story about the data
# - Clearly document (within the notebook) 5 different insights you gained from the data

# %% [markdown]
# # Feature Engineering
# - Convert categorical or non-numeric features into a numerical representation
# - Transform neccessary features using feature transformation techniques of your choice.

# %%
#feature engineering
#convert genre to numerical values
df_without_artist['genre'] = df['genre'].map({'Classical':0,'Country':1,'EDM':2,'Rap':3,'Rock':4})
df_without_song['genre'] = df['genre'].map({'Classical':0,'Country':1,'EDM':2,'Rap':3,'Rock':4})
df_without_artist_song['genre'] = df['genre'].map({'Classical':0,'Country':1,'EDM':2,'Rap':3,'Rock':4})

#standardize the data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
numerical_columns = df_without_artist_song.drop(['genre'],axis=1).columns
df_without_artist_song[numerical_columns] = scaler.fit_transform(df_without_artist_song[numerical_columns])

df_without_artist_song.head()
# Out:
#    genre  acousticness  danceability  duration_ms    energy  instrumentalness  \
# 0      4      1.041974      0.295349     1.011195 -0.091078         -0.513893
# 1      4     -0.927958     -1.313484    -0.112706  1.199020         -0.522657
# 2      4     -0.923408     -0.302881     0.340258  1.039530         -0.522439
# 3      4     -0.919270     -0.570052     0.996399  1.053707         -0.505827
# 4      4     -0.740801      0.620601    -0.931794  0.585869         -0.522657
#
#         key  liveness  loudness  speechiness     tempo      mode   valence
# 0  1.287656 -0.811310 -0.263009    -0.240240 -0.353754 -1.333333 -1.112988
# 1 -1.227298 -0.442531  0.593970     0.045146  1.197124  0.750000 -0.957582
# 2 -1.506737 -0.489690  0.529694    -0.214164  0.893385  0.750000 -0.909765
# 3 -1.227298 -0.601927  0.641526    -0.512587  1.741484  0.750000  0.429116
# 4  0.728778 -0.173728  0.682676    -0.175050 -0.173983  0.750000  1.289826

# %% [markdown]
# # Machine Learning
# - Use 2 different ML algorithms to build a model using your preprocessed data.
# - Compare the 2 models based on their accuracy.

# %%
#split the data into training and testing sets
from sklearn.model_selection import train_test_split
X = df_without_artist_song.drop(['genre'],axis=1)
y = df_without_artist_song['genre']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

#train the model logistic regression
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(random_state=54)
lr.fit(X_train,y_train)

#import random forest classifier
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=100,random_state=54)
rfc.fit(X_train,y_train)

#make predictions
predictions_knn = lr.predict(X_test)
predictions_rfc = rfc.predict(X_test)

#import svm
from sklearn.svm import SVC
svc = SVC(random_state=54)
svc.fit(X_train,y_train)
predictions_svc = svc.predict(X_test)


#compare based on accuracy
from sklearn.metrics import accuracy_score
print("KNN:")
print(accuracy_score(y_test,predictions_knn))
print("Random Forest:")
print(accuracy_score(y_test,predictions_rfc))
print("SVM:")
print(accuracy_score(y_test,predictions_svc))
# Out:
# KNN:
# 0.72
# Random Forest:
# 0.82
# SVM:
# 0.64

# %% [markdown]
# # Model Evaluation
# - Evaluate the 2 models using a minimum of 4 evaluation metrics

# %% [markdown]
# # Deployment
# - Able to deploy the ML model to cloud.
# - Provides a live working URL to the deployed app.
